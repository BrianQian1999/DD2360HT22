# %% [markdown]
# # CPU Version

# %%
# !nvcc --version
# !nvidia-smi
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2021 NVIDIA Corporation
# Built on Sun_Feb_14_21:12:58_PST_2021
# Cuda compilation tools, release 11.2, V11.2.152
# Build cuda_11.2.r11.2/compiler.29618528_0
# Mon Jan  2 21:36:06 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P0    26W /  70W |      0MiB / 15109MiB |      0%      Default |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/Colab Notebooks/sputniPIC-DD2360-master"
# Out:
# bin  HW3_Ex_4.ipynb  include  inputfiles  Makefile  src

# %%
# %cd "/content/drive/My Drive/Colab Notebooks/sputniPIC-DD2360-master"
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/sputniPIC-DD2360-master
# /content/drive/My Drive/Colab Notebooks/sputniPIC-DD2360-master

# %%
# !make
# Out:
# nvcc -I./include -arch=sm_75 -std=c++11 -O3 -g -Xcompiler -Wall --compiler-bindir=g++ src/Particles.cu -c -o src/Particles.o
# src/Particles.cu: In function ‘int mover_PC(particles*, EMfield*, grid*, parameters*)’:
# src/Particles.cu:162:38: warning: ‘wptilde’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#              part->z[i] = zptilde + wptilde*dt_sub_cycling;
#                              ~~~~~~~~~^~~~~~~~~~~~~~~~~
# src/Particles.cu:158:26: warning: ‘vptilde’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#              part->v[i]= 2.0*vptilde - part->v[i];
#                    ~~~~~~~^~~~~~~~~~
# src/Particles.cu:157:26: warning: ‘uptilde’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#              part->u[i]= 2.0*uptilde - part->u[i];
#                    ~~~~~~~^~~~~~~~~~
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall src/ConfigFile.cpp -c -o src/ConfigFile.o
# ...

# %%
# !./bin/sputniPIC.out inputfiles/GEM_2D.inp
# Out:
# -------------------------
# sputniPIC Sim. Parameters
# -------------------------
# Number of species    = 4
# Number of particles of species 0 = 4096000	 (MAX = 4096000)  QOM = -64
# Number of particles of species 1 = 4096000	 (MAX = 4096000)  QOM = 1
# Number of particles of species 2 = 4096000	 (MAX = 4096000)  QOM = -64
# Number of particles of species 3 = 4096000	 (MAX = 4096000)  QOM = 1
# x-Length                 = 40
# y-Length                 = 20
# z-Length                 = 1
# Number of cells (x)      = 256
# Number of cells (y)      = 128
# Number of cells (z)      = 1
# Time step                = 0.25
# Number of cycles         = 10
# Results saved in: data
# *************************************************
# **  Initialize GEM Challenge with Pertubation  **
# *************************************************
# ** B0x = 0.0195
# ** B0y = 0
# ** B0z = 0
# ** Delta (current sheet thickness) = 0.5
# ** rho species 0 = 1 CURRENT SHEET
# ** rho species 1 = 1 CURRENT SHEET
# ...

# %% [markdown]
# # GPU Version cudaMalloc

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/My Drive/Colab Notebooks/sputniPIC-DD2360-master"
# !pwd
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-285e5a3a0a1d> in <module>
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#       3 get_ipython().run_line_magic('cd', '"/content/drive/My Drive/Colab Notebooks/sputniPIC-DD2360-master"')
#       4 get_ipython().system('pwd')
#
# /usr/local/lib/python3.8/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      99 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     100   """Mount your Google Drive at the specified mountpoint path."""
# --> 101   return _mount(
#     102       mountpoint,
#     103       force_remount=force_remount,
#
# /usr/local/lib/python3.8/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
# ...

# %%
# !make clean
# !make

# %%
# !./bin/sputniPIC.out inputfiles/GEM_2D.inp

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/My Drive/Colab Notebooks/sputniPIC-DD2360-master"
# !pwd

# %% [markdown]
# # Pinned Memory

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/My Drive/Colab Notebooks/Pinned_final"
# !pwd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Colab Notebooks/Pinned_final
# /content/drive/My Drive/Colab Notebooks/Pinned_final

# %%
# !make clean
# !make
# Out:
# rm -rf  src/Basic.o src/RW_IO.o src/Particles_aux.o src/TransArraySpace3D.o src/ConfigFile.o src/BC.o src/Timing.o src/InterpDensNet.o src/EMfield_aux.o src/EMfield.o src/InterpDensSpecies.o src/Grid.o src/sputniPIC.o src/Particles.o
# rm -rf sputniPIC.out
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall src/Basic.cpp -c -o src/Basic.o
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall src/RW_IO.cpp -c -o src/RW_IO.o
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall src/Particles_aux.cpp -c -o src/Particles_aux.o
# src/Particles_aux.cpp: In function ‘void particle_aux_allocate(particles*, particles_aux*, int)’:
# src/Particles_aux.cpp:14:10: warning: unused variable ‘npmax’ [-Wunused-variable]
#      long npmax = part->npmax;
#           ^~~~~
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall src/TransArraySpace3D.cpp -c -o src/TransArraySpace3D.o
# ...

# %%
# !/usr/local/cuda-11/bin/nv-nsight-cu-cli ./bin/sputniPIC.out inputfiles/GEM_2D.inp
# Out:
# -------------------------
# sputniPIC Sim. Parameters
# -------------------------
# Number of species    = 4
# Number of particles of species 0 = 4096000	 (MAX = 4096000)  QOM = -64
# Number of particles of species 1 = 4096000	 (MAX = 4096000)  QOM = 1
# Number of particles of species 2 = 4096000	 (MAX = 4096000)  QOM = -64
# Number of particles of species 3 = 4096000	 (MAX = 4096000)  QOM = 1
# x-Length                 = 40
# y-Length                 = 20
# z-Length                 = 1
# Number of cells (x)      = 256
# Number of cells (y)      = 128
# Number of cells (z)      = 1
# Time step                = 0.25
# Number of cycles         = 10
# Results saved in: data
# ==PROF== Connected to process 3045 (/content/drive/MyDrive/Colab Notebooks/Pinned_final/bin/sputniPIC.out)
# *************************************************
# **  Initialize GEM Challenge with Pertubation  **
# *************************************************
# ** B0x = 0.0195
# ** B0y = 0
# ** B0z = 0
# ...

# %% [markdown]
# # Unified Memory

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/My Drive/Colab Notebooks/sputniPIC-DD2360-master"
# !pwd
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks/sputniPIC-DD2360-master
# /content/drive/My Drive/Colab Notebooks/sputniPIC-DD2360-master

# %%
# !make clean
# !make
# Out:
# rm -rf  src/ConfigFile.o src/InterpDensNet.o src/Basic.o src/Particles_aux.o src/TransArraySpace3D.o src/Timing.o src/BC.o src/RW_IO.o src/Particles.o src/Grid.o src/InterpDensSpecies.o src/sputniPIC.o src/EMfield_aux.o src/EMfield.o
# rm -rf sputniPIC.out
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall src/ConfigFile.cpp -c -o src/ConfigFile.o
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall src/InterpDensNet.cpp -c -o src/InterpDensNet.o
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall src/Basic.cpp -c -o src/Basic.o
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall src/Particles_aux.cpp -c -o src/Particles_aux.o
# src/Particles_aux.cpp: In function ‘void particle_aux_allocate(particles*, particles_aux*, int)’:
# src/Particles_aux.cpp:14:10: warning: unused variable ‘npmax’ [-Wunused-variable]
#      long npmax = part->npmax;
#           ^~~~~
# ...

# %%
# !./bin/sputniPIC.out inputfiles/GEM_2D.inp
# Out:
# -------------------------
# sputniPIC Sim. Parameters
# -------------------------
# Number of species    = 4
# Number of particles of species 0 = 4096000	 (MAX = 4096000)  QOM = -64
# Number of particles of species 1 = 4096000	 (MAX = 4096000)  QOM = 1
# Number of particles of species 2 = 4096000	 (MAX = 4096000)  QOM = -64
# Number of particles of species 3 = 4096000	 (MAX = 4096000)  QOM = 1
# x-Length                 = 40
# y-Length                 = 20
# z-Length                 = 1
# Number of cells (x)      = 256
# Number of cells (y)      = 128
# Number of cells (z)      = 1
# Time step                = 0.25
# Number of cycles         = 10
# Results saved in: data

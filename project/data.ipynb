# %%
# !nvcc --version
# !nvidia-smi
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2021 NVIDIA Corporation
# Built on Sun_Feb_14_21:12:58_PST_2021
# Cuda compilation tools, release 11.2, V11.2.152
# Build cuda_11.2.r11.2/compiler.29618528_0
# Sat Jan  7 22:38:43 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   53C    P0    27W /  70W |      0MiB / 15109MiB |      0%      Default |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Baseline

# %%
# %cd "/content/drive/My Drive/Colab Notebooks/dd2360-project/sputniPIC"
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/dd2360-project/sputniPIC
# /content/drive/My Drive/Colab Notebooks/dd2360-project/sputniPIC

# %%
# !make clean
# !make
# Out:
# rm -rf  src/Timing.o src/EMfield_aux.o src/BC.o src/RW_IO.o src/Basic.o src/Particles.o src/sputniPIC.o src/InterpDensNet.o src/TransArraySpace3D.o src/Grid.o src/EMfield.o src/ConfigFile.o src/InterpDensSpecies.o src/Particles_aux.o
# rm -rf sputniPIC.out
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall src/Timing.cpp -c -o src/Timing.o
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall src/EMfield_aux.cpp -c -o src/EMfield_aux.o
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall src/BC.cpp -c -o src/BC.o
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall src/RW_IO.cpp -c -o src/RW_IO.o
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall src/Basic.cpp -c -o src/Basic.o
# nvcc -I./include -arch=sm_75 -std=c++11 -O3 -g -Xcompiler -Wall --compiler-bindir=g++ src/Particles.cu -c -o src/Particles.o
# ...

# %%
# !nvprof ./bin/sputniPIC.out inputfiles/GEM_2D.inp
# Out:
# -------------------------
# sputniPIC Sim. Parameters
# -------------------------
# Number of species    = 4
# Number of particles of species 0 = 4096000	 (MAX = 4096000)  QOM = -64
# Number of particles of species 1 = 4096000	 (MAX = 4096000)  QOM = 1
# Number of particles of species 2 = 4096000	 (MAX = 4096000)  QOM = -64
# Number of particles of species 3 = 4096000	 (MAX = 4096000)  QOM = 1
# x-Length                 = 40
# y-Length                 = 20
# z-Length                 = 1
# Number of cells (x)      = 256
# Number of cells (y)      = 128
# Number of cells (z)      = 1
# Time step                = 0.25
# Number of cycles         = 10
# Results saved in: data
# *************************************************
# **  Initialize GEM Challenge with Pertubation  **
# *************************************************
# ** B0x = 0.0195
# ** B0y = 0
# ** B0z = 0
# ** Delta (current sheet thickness) = 0.5
# ** rho species 0 = 1 CURRENT SHEET
# ** rho species 1 = 1 CURRENT SHEET
# ...

# %%
# !nvprof ./bin/sputniPIC.out inputfiles/GEM_3D.inp
# Out:
# -------------------------
# sputniPIC Sim. Parameters
# -------------------------
# Number of species    = 4
# Number of particles of species 0 = 14155776	 (MAX = 14155776)  QOM = -64
# Number of particles of species 1 = 14155776	 (MAX = 14155776)  QOM = 1
# Number of particles of species 2 = 14155776	 (MAX = 14155776)  QOM = -64
# Number of particles of species 3 = 14155776	 (MAX = 14155776)  QOM = 1
# x-Length                 = 20
# y-Length                 = 10
# z-Length                 = 10
# Number of cells (x)      = 128
# Number of cells (y)      = 64
# Number of cells (z)      = 64
# Time step                = 0.25
# Number of cycles         = 10
# Results saved in: data
# *************************************************
# **  Initialize GEM Challenge with Pertubation  **
# *************************************************
# ** B0x = 0.0097
# ** B0y = 0
# ** B0z = 0
# ** Delta (current sheet thickness) = 0.5
# ** rho species 0 = 1 CURRENT SHEET
# ...

# %% [markdown]
# # CudaMalloc

# %%
# %cd "/content/drive/My Drive/Colab Notebooks/dd2360-project/sputniPIC-MALLOC"
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/dd2360-project/sputniPIC-MALLOC
# /content/drive/My Drive/Colab Notebooks/dd2360-project/sputniPIC-MALLOC

# %%
# !make clean
# !make
# Out:
# rm -rf  src/Basic.o src/EMfield.o src/RW_IO.o src/Timing.o src/InterpDensNet.o src/Particles_aux.o src/Particles.o src/TransArraySpace3D.o src/EMfield_aux.o src/Grid.o src/ConfigFile.o src/BC.o src/InterpDensSpecies.o src/sputniPIC.o
# rm -rf sputniPIC.out
# mkdir -p ./bin
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall src/Basic.cpp -c -o src/Basic.o
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall src/EMfield.cpp -c -o src/EMfield.o
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall src/RW_IO.cpp -c -o src/RW_IO.o
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall src/Timing.cpp -c -o src/Timing.o
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall src/InterpDensNet.cpp -c -o src/InterpDensNet.o
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall src/Particles_aux.cpp -c -o src/Particles_aux.o
# ...

# %%
# !nvprof ./bin/sputniPIC.out inputfiles/GEM_2D.inp
# Out:
# -------------------------
# sputniPIC Sim. Parameters
# -------------------------
# Number of species    = 4
# Number of particles of species 0 = 4096000	 (MAX = 4096000)  QOM = -64
# Number of particles of species 1 = 4096000	 (MAX = 4096000)  QOM = 1
# Number of particles of species 2 = 4096000	 (MAX = 4096000)  QOM = -64
# Number of particles of species 3 = 4096000	 (MAX = 4096000)  QOM = 1
# x-Length                 = 40
# y-Length                 = 20
# z-Length                 = 1
# Number of cells (x)      = 256
# Number of cells (y)      = 128
# Number of cells (z)      = 1
# Time step                = 0.25
# Number of cycles         = 10
# Results saved in: data
# *************************************************
# **  Initialize GEM Challenge with Pertubation  **
# *************************************************
# ** B0x = 0.0195
# ** B0y = 0
# ** B0z = 0
# ** Delta (current sheet thickness) = 0.5
# ** rho species 0 = 1 CURRENT SHEET
# ** rho species 1 = 1 CURRENT SHEET
# ...

# %%
# !nvprof ./bin/sputniPIC.out inputfiles/GEM_3D.inp
# Out:
# -------------------------
# sputniPIC Sim. Parameters
# -------------------------
# Number of species    = 4
# Number of particles of species 0 = 14155776	 (MAX = 14155776)  QOM = -64
# Number of particles of species 1 = 14155776	 (MAX = 14155776)  QOM = 1
# Number of particles of species 2 = 14155776	 (MAX = 14155776)  QOM = -64
# Number of particles of species 3 = 14155776	 (MAX = 14155776)  QOM = 1
# x-Length                 = 20
# y-Length                 = 10
# z-Length                 = 10
# Number of cells (x)      = 128
# Number of cells (y)      = 64
# Number of cells (z)      = 64
# Time step                = 0.25
# Number of cycles         = 10
# Results saved in: data
# *************************************************
# **  Initialize GEM Challenge with Pertubation  **
# *************************************************
# ** B0x = 0.0097
# ** B0y = 0
# ** B0z = 0
# ** Delta (current sheet thickness) = 0.5
# ** rho species 0 = 1 CURRENT SHEET
# ...

# %% [markdown]
# # Pinned Memory

# %%
# %cd "/content/drive/My Drive/Colab Notebooks/dd2360-project/sputniPIC-PINNED"
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/dd2360-project/sputniPIC-PINNED
# /content/drive/My Drive/Colab Notebooks/dd2360-project/sputniPIC-PINNED

# %%
# !make clean
# !make
# Out:
# rm -rf  src/Timing.o src/Particles.o src/InterpDensSpecies.o src/Grid.o src/RW_IO.o src/EMfield.o src/Particles_aux.o src/ConfigFile.o src/BC.o src/InterpDensNet.o src/TransArraySpace3D.o src/EMfield_aux.o src/Basic.o src/sputniPIC.o
# rm -rf sputniPIC.out
# mkdir -p ./bin
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall src/Timing.cpp -c -o src/Timing.o
# nvcc -I./include -arch=sm_75 -std=c++11 -O3 -g -Xcompiler -Wall --compiler-bindir=g++ src/Particles.cu -c -o src/Particles.o
# src/Particles.cu: In function ‘int mover_PC(particles*, EMfield*, grid*, parameters*)’:
# src/Particles.cu:172:38: warning: ‘wptilde’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#              part->z[i] = zptilde + wptilde*dt_sub_cycling;
#                              ~~~~~~~~~^~~~~~~~~~~~~~~~~
# src/Particles.cu:168:26: warning: ‘vptilde’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# ...

# %%
# !nvprof ./bin/sputniPIC.out inputfiles/GEM_2D.inp
# Out:
# -------------------------
# sputniPIC Sim. Parameters
# -------------------------
# Number of species    = 4
# Number of particles of species 0 = 4096000	 (MAX = 4096000)  QOM = -64
# Number of particles of species 1 = 4096000	 (MAX = 4096000)  QOM = 1
# Number of particles of species 2 = 4096000	 (MAX = 4096000)  QOM = -64
# Number of particles of species 3 = 4096000	 (MAX = 4096000)  QOM = 1
# x-Length                 = 40
# y-Length                 = 20
# z-Length                 = 1
# Number of cells (x)      = 256
# Number of cells (y)      = 128
# Number of cells (z)      = 1
# Time step                = 0.25
# Number of cycles         = 10
# Results saved in: data
# ==9054== NVPROF is profiling process 9054, command: ./bin/sputniPIC.out inputfiles/GEM_2D.inp
# *************************************************
# **  Initialize GEM Challenge with Pertubation  **
# *************************************************
# ** B0x = 0.0195
# ** B0y = 0
# ** B0z = 0
# ...

# %%
# !nvprof ./bin/sputniPIC.out inputfiles/GEM_3D.inp
# Out:
# -------------------------
# sputniPIC Sim. Parameters
# -------------------------
# Number of species    = 4
# Number of particles of species 0 = 14155776	 (MAX = 14155776)  QOM = -64
# Number of particles of species 1 = 14155776	 (MAX = 14155776)  QOM = 1
# Number of particles of species 2 = 14155776	 (MAX = 14155776)  QOM = -64
# Number of particles of species 3 = 14155776	 (MAX = 14155776)  QOM = 1
# x-Length                 = 20
# y-Length                 = 10
# z-Length                 = 10
# Number of cells (x)      = 128
# Number of cells (y)      = 64
# Number of cells (z)      = 64
# Time step                = 0.25
# Number of cycles         = 10
# Results saved in: data
# ==9578== NVPROF is profiling process 9578, command: ./bin/sputniPIC.out inputfiles/GEM_3D.inp
# *************************************************
# **  Initialize GEM Challenge with Pertubation  **
# *************************************************
# ** B0x = 0.0097
# ** B0y = 0
# ** B0z = 0
# ...

# %% [markdown]
# # Unified Memory

# %%
# %cd "/content/drive/My Drive/Colab Notebooks/dd2360-project/sputniPIC-UM"
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/dd2360-project/sputniPIC-UM
# /content/drive/My Drive/Colab Notebooks/dd2360-project/sputniPIC-UM

# %%
# !make clean
# !make
# Out:
# rm -rf  src/TransArraySpace3D.o src/sputniPIC.o src/RW_IO.o src/ConfigFile.o src/BC.o src/InterpDensSpecies.o src/InterpDensNet.o src/Particles_aux.o src/EMfield_aux.o src/EMfield.o src/Particles.o src/Timing.o src/Basic.o src/Grid.o
# rm -rf sputniPIC.out
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall src/TransArraySpace3D.cpp -c -o src/TransArraySpace3D.o
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall src/sputniPIC.cpp -c -o src/sputniPIC.o
# In file included from src/sputniPIC.cpp:27:0:
# ./include/IC.h: In function ‘void initGEM(parameters*, grid*, EMfield*, EMfield_aux*, particles*, interpDensSpecies*)’:
# ./include/IC.h:82:25: warning: unused variable ‘sign’ [-Wunused-variable]
#      double prob, theta, sign;
#                          ^~~~
# [ -d src ] || mkdir src
# nvcc -std=c++11 -I./include -O3 -g -Xcompiler -Wall src/RW_IO.cpp -c -o src/RW_IO.o
# [ -d src ] || mkdir src
# ...

# %%
# !nvprof ./bin/sputniPIC.out inputfiles/GEM_2D.inp
# Out:
# -------------------------
# sputniPIC Sim. Parameters
# -------------------------
# Number of species    = 4
# Number of particles of species 0 = 4096000	 (MAX = 4096000)  QOM = -64
# Number of particles of species 1 = 4096000	 (MAX = 4096000)  QOM = 1
# Number of particles of species 2 = 4096000	 (MAX = 4096000)  QOM = -64
# Number of particles of species 3 = 4096000	 (MAX = 4096000)  QOM = 1
# x-Length                 = 40
# y-Length                 = 20
# z-Length                 = 1
# Number of cells (x)      = 256
# Number of cells (y)      = 128
# Number of cells (z)      = 1
# Time step                = 0.25
# Number of cycles         = 10
# Results saved in: data
# ==15545== NVPROF is profiling process 15545, command: ./bin/sputniPIC.out inputfiles/GEM_2D.inp
# *************************************************
# **  Initialize GEM Challenge with Pertubation  **
# *************************************************
# ** B0x = 0.0195
# ** B0y = 0
# ** B0z = 0
# ...

# %%
# !nvprof ./bin/sputniPIC.out inputfiles/GEM_3D.inp
# Out:
# -------------------------
# sputniPIC Sim. Parameters
# -------------------------
# Number of species    = 4
# Number of particles of species 0 = 14155776	 (MAX = 14155776)  QOM = -64
# Number of particles of species 1 = 14155776	 (MAX = 14155776)  QOM = 1
# Number of particles of species 2 = 14155776	 (MAX = 14155776)  QOM = -64
# Number of particles of species 3 = 14155776	 (MAX = 14155776)  QOM = 1
# x-Length                 = 20
# y-Length                 = 10
# z-Length                 = 10
# Number of cells (x)      = 128
# Number of cells (y)      = 64
# Number of cells (z)      = 64
# Time step                = 0.25
# Number of cycles         = 10
# Results saved in: data
# ==16853== NVPROF is profiling process 16853, command: ./bin/sputniPIC.out inputfiles/GEM_3D.inp
# *************************************************
# **  Initialize GEM Challenge with Pertubation  **
# *************************************************
# ** B0x = 0.0097
# ** B0y = 0
# ** B0z = 0
# ...
